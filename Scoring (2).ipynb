# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, precision_score 
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import pickle

# %%
data = pd.read_excel('Dataset.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2953 entries, 0 to 2952
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 2910 non-null   object
#  1   Возраст                                                             2910 non-null   object
#  2   Семейное положение                                                  2910 non-null   object
#  3   Национальность                                                      2910 non-null   object
#  4   Повторный клиент                                                    2910 non-null   object
#  5   Сумма выдачи номинал                                                2910 non-null   float64
#  6   Дата выдачи                                                         2910 non-null   object
# ...

# %%
data.loc[data['Пол'] == 'Жен', 'пол'] = 0
data.loc[data['Пол'] == 'Муж', 'пол'] = 1

# %%
data = data.drop(['Возраст'], axis=1)
data = data.drop(['Национальность'], axis=1)
data = data.drop(['Дата выдачи'], axis=1)
data = data.drop(['Дата окончание срока'], axis=1)
data = data.drop(['Валюта'], axis=1)
data = data.drop(['Дата списания'], axis=1)
data = data.drop(['Сумма списания'], axis=1)
data = data.drop(['Пол'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2953 entries, 0 to 2952
# Data columns (total 13 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Семейное положение                                                  2910 non-null   object
#  1   Повторный клиент                                                    2910 non-null   object
#  2   Сумма выдачи номинал                                                2910 non-null   float64
#  3   Срок                                                                2910 non-null   float64
#  4   Тип залога                                                          2910 non-null   object
#  5   Образование                                                         2910 non-null   object
#  6   Тип бизнеса                                                         2910 non-null   object
# ...

# %%
data['Семейное положение'] = data['Семейное положение'].astype('category')
data['Семейное положение'] = data['Семейное положение'].cat.codes
data
# Out:
#       Семейное положение Повторный клиент  Сумма выдачи номинал  Срок  \
# 0                      1    Старый клиент              200000.0  18.0
# 1                      1    Старый клиент               88000.0  24.0
# 2                      1    Старый клиент               60000.0  12.0
# 3                      1    Старый клиент              120000.0  25.0
# 4                      1    Старый клиент              250000.0  12.0
# ...                  ...              ...                   ...   ...
# 2948                   1    Старый клиент               15000.0  18.0
# 2949                   3    Старый клиент                6500.0  24.0
# 2950                   1    Старый клиент               25000.0  26.0
# 2951                   1    Старый клиент               20800.0  24.0
# 2952                   1    Старый клиент                8500.0  12.0
#
#                  Тип залога          Образование             Тип бизнеса  \
# ...

# %%
data['Повторный клиент'] = data['Повторный клиент'].astype('category')
data['Повторный клиент'] = data['Повторный клиент'].cat.codes
data
# Out:
#       Семейное положение  Повторный клиент  Сумма выдачи номинал  Срок  \
# 0                      1                 1              200000.0  18.0
# 1                      1                 1               88000.0  24.0
# 2                      1                 1               60000.0  12.0
# 3                      1                 1              120000.0  25.0
# 4                      1                 1              250000.0  12.0
# ...                  ...               ...                   ...   ...
# 2948                   1                 1               15000.0  18.0
# 2949                   3                 1                6500.0  24.0
# 2950                   1                 1               25000.0  26.0
# 2951                   1                 1               20800.0  24.0
# 2952                   1                 1                8500.0  12.0
#
#                  Тип залога          Образование             Тип бизнеса  \
# ...

# %%
data['Тип залога'] = data['Тип залога'].astype('category')
data['Тип залога'] = data['Тип залога'].cat.codes

# %%
data['Образование'] = data['Образование'].astype('category')
data['Образование'] = data['Образование'].cat.codes

# %%
data['Тип бизнеса'] = data['Тип бизнеса'].astype('category')
data['Тип бизнеса'] = data['Тип бизнеса'].cat.codes

# %%
data['Цель кредита'] = data['Цель кредита'].astype('category')
data['Цель кредита'] = data['Цель кредита'].cat.codes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2953 entries, 0 to 2952
# Data columns (total 13 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Семейное положение                                                  2953 non-null   int8
#  1   Повторный клиент                                                    2953 non-null   int8
#  2   Сумма выдачи номинал                                                2910 non-null   float64
#  3   Срок                                                                2910 non-null   float64
#  4   Тип залога                                                          2953 non-null   int8
#  5   Образование                                                         2953 non-null   int8
#  6   Тип бизнеса                                                         2953 non-null   int8
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2910 entries, 0 to 2952
# Data columns (total 13 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Семейное положение                                                  2910 non-null   int8
#  1   Повторный клиент                                                    2910 non-null   int8
#  2   Сумма выдачи номинал                                                2910 non-null   float64
#  3   Срок                                                                2910 non-null   float64
#  4   Тип залога                                                          2910 non-null   int8
#  5   Образование                                                         2910 non-null   int8
#  6   Тип бизнеса                                                         2910 non-null   int8
# ...

# %%
data.corr()
# Out:
#                                                     Семейное положение  \
# Семейное положение                                            1.000000
# Повторный клиент                                             -0.061252
# Сумма выдачи номинал                                          0.003069
# Срок                                                         -0.034025
# Тип залога                                                   -0.010486
# Образование                                                  -0.043525
# Тип бизнеса                                                  -0.020730
# Цель кредита                                                  0.014035
# Просрочки за цикл (кумулятивный)                              0.008571
# Длительность самой долгой единовременной просро...            0.007210
# Просрочки на дату 07.06.2021                                  0.010393
# Льготный период                                              -0.010708
# ...

# %%
data = data.drop(['Цель кредита'], axis=1)
data = data.drop(['Льготный период'], axis=1)
data = data.drop(['Тип бизнеса'], axis=1)
data = data.drop(['Сумма выдачи номинал'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2910 entries, 0 to 2952
# Data columns (total 9 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Семейное положение                                                  2910 non-null   int8
#  1   Повторный клиент                                                    2910 non-null   int8
#  2   Срок                                                                2910 non-null   float64
#  3   Тип залога                                                          2910 non-null   int8
#  4   Образование                                                         2910 non-null   int8
#  5   Просрочки за цикл (кумулятивный)                                    2910 non-null   float64
#  6   Длительность самой долгой единовременной просрочки в течение цикла  2910 non-null   float64
# ...

# %%
data = data.drop(['Образование'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2910 entries, 0 to 2952
# Data columns (total 8 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Семейное положение                                                  2910 non-null   int8
#  1   Повторный клиент                                                    2910 non-null   int8
#  2   Срок                                                                2910 non-null   float64
#  3   Тип залога                                                          2910 non-null   int8
#  4   Просрочки за цикл (кумулятивный)                                    2910 non-null   float64
#  5   Длительность самой долгой единовременной просрочки в течение цикла  2910 non-null   float64
#  6   Просрочки на дату 07.06.2021                                        2910 non-null   float64
# ...

# %%
data.corr()
# Out:
#                                                     Семейное положение  \
# Семейное положение                                            1.000000
# Повторный клиент                                             -0.061252
# Срок                                                         -0.034025
# Тип залога                                                   -0.010486
# Просрочки за цикл (кумулятивный)                              0.008571
# Длительность самой долгой единовременной просро...            0.007210
# Просрочки на дату 07.06.2021                                  0.010393
# пол                                                          -0.000491
#
#                                                     Повторный клиент  \
# Семейное положение                                         -0.061252
# Повторный клиент                                            1.000000
# Срок                                                        0.113745
# ...
